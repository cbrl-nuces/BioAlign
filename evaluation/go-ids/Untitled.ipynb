# %%
f = open("yeast_ann_MF.txt")
lines = f.readlines()
f.close()

print (len(lines))
# Out:
# 5036

# %%
count=0
for i in range(len(lines)):
    tokens = lines[i].strip("\n").split("#")
    print (len(tokens),tokens)
    if len(tokens) == 1:
        count+=1
        
print (count)
# Out:
# 2 ['Q07978', 'GO:0003674']
# 2 ['Q08964', 'GO:0003674']
# 2 ['Q12234', 'GO:0031267,GO:0051020,GO:0005515']
# 2 ['Q99316', 'GO:0016853,GO:0003756,GO:0015035']
# 2 ['P06103', 'GO:0031369,GO:0003676,GO:0003723,GO:0003743,GO:0042802,GO:0005515']
# 2 ['Q04067', 'GO:0003676,GO:0003723,GO:0003743,GO:0005515']
# 2 ['P06104', 'GO:0061631,GO:0005524,GO:0016740,GO:0000166,GO:0017116,GO:0004842,GO:0003697,GO:0070628,GO:0005515']
# 2 ['P10862', 'GO:0003677,GO:0003697,GO:0061630,GO:0016740,GO:0046872,GO:0017116,GO:0005515']
# 2 ['P32773', 'GO:0017025,GO:0003712,GO:0005515,GO:0000979']
# 2 ['P32803', 'GO:0003674,GO:0005515']
# 2 ['P36058', 'GO:0003674']
# 2 ['Q07963', 'GO:0061630,GO:0008270,GO:0016740,GO:0046872,GO:0004842,GO:0005515']
# 2 ['Q08237', 'GO:0004527,GO:0008408,GO:0003676,GO:0016787,GO:0004518']
# 2 ['P06105', 'GO:0003729,GO:0003676,GO:0003723,GO:0001965']
# 2 ['P08539', 'GO:0031683,GO:0001664,GO:0003924,GO:0005525,GO:0019001,GO:0000166,GO:0046872,GO:0031681,GO:0005515']
# ...

# %%
# Yeast BP = 762
# MF = 1387
